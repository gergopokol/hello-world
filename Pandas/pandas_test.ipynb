# %% [markdown]
# # XML read-write test

# %% [markdown]
# ## Austin Taylor
#
# http://www.austintaylor.io/lxml/python/pandas/xml/dataframe/2016/07/08/convert-xml-to-pandas-dataframe/

# %%
import requests

user_agent_url = 'http://www.user-agents.org/allagents.xml'
xml_data = requests.get(user_agent_url).content

# %%
import xml.etree.ElementTree as ET
import pandas as pd

class XML2DataFrame:

    def __init__(self, xml_data):
        self.root = ET.XML(xml_data)

    def parse_root(self, root):
        return [self.parse_element(child) for child in iter(root)]

    def parse_element(self, element, parsed=None):
        if parsed is None:
            parsed = dict()
        for key in element.keys():
            parsed[key] = element.attrib.get(key)
        if element.text:
            parsed[element.tag] = element.text
        for child in list(element):
            self.parse_element(child, parsed)
        return parsed

    def process_data(self):
        structure_data = self.parse_root(self.root)
        return pd.DataFrame(structure_data)

xml2df = XML2DataFrame(xml_data)
xml_dataframe = xml2df.process_data()

# %%
xml_dataframe
# Out:
#                                                 Comment  \
# 0                                                   NaN
# 1                                          Site is dead
# 2                                          Site is dead
# 3                                          Site is dead
# 4                                       s.also SygolBot
# 5                         Services is no more available
# 6                                                   NaN
# 7                        s.also Privoxy/3.0 (Anonymous)
# 8                                       123.113.184.2xx
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                       217.160.75.2xx
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                           s. various honey pot sites
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                          192.9.71.7x
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26    s. also - np/0.1_(np;_http://www.nameprotect.c...
# 27                                                  NaN
# 28                                      125.100.242.2xx
# 29                                         65.17.255.xx
# ...                                                 ...
# 2429  s. also Mozilla/5.0 (compatible; Yoono; http:/...
# 2430                           s. also OmniExplorer_Bot
# 2431                           s. also OmniExplorer_Bot
# 2432                                     s. Y!TunnelPro
# 2433                                                NaN
# 2434                                                NaN
# 2435                                                NaN
# 2436                                                NaN
# 2437                                                NaN
# 2438                                    212.227.109.1xx
# 2439                                     213.251.135.xx
# 2440                                     213.251.135.xx
# 2441                                       24.62.50.1xx
# 2442                                                NaN
# 2443                                      67.202.34.xxx
# 2444                                     138.88.147.xxx
# 2445                                                NaN
# 2446                                                NaN
# 2447                                   powered by Nutch
# 2448                                                NaN
# 2449                                                NaN
# 2450                                                NaN
# 2451                                                NaN
# 2452                                                NaN
# 2453                                                NaN
# 2454                                                  R
# 2455                                                NaN
# 2456                                                NaN
# 2457                                                NaN
# 2458                                                NaN
#
#                                             Description               ID  \
# 0       Sync2It bookmark management & clustering engine         id_a_f_3
# 1                                  UnCHAOS search robot         id_a_f_6
# 2                                  UnCHAOS search robot         id_a_f_7
# 3                                  UnCHAOS search robot         id_a_f_8
# 4                            Sygol Search (Italy) robot         id_a_f_9
# 5              SearchEngineWorld's robots.txt validator         id_a_f_4
# 6                       DreamCast DreamPassport browser  id_a_f_171105_1
# 7                                     Privoxy web proxy  id_a_f_290606_1
# 8                                   Unknown Yahoo robot  id_a_f_230507_1
# 9                     SitiDi.net search (Germany) robot         id_a_f_5
# 10    Die Kraehe Meta-Search-Engine (Germany) link c...         id_a_f_1
# 11    123spider.de (Germany) web directory link chec...  id_a_f_060206_1
# 12                           192.com - UK web directory  id_a_f_180806_1
# 13              1st ZipCommander Net - IE based browser  id_a_f_060606_1
# 14                            2Bone online link checker        id_a_f_10
# 15                                      4Anything robot        id_a_f_11
# 16    Unknown guestbook spamming or harvesting tool ...  id_a_f_110207_1
# 17                        neofonie search robot Germany         id_a_f_2
# 18               A-Online.at robot - now Jet2Web Search        id_a_f_12
# 19    A1 Keyword Research - search engine and keywor...  id_a_f_090707_1
# 20    MiggiBot website crawler engine - A1 Sitemap G...  id_a_f_100906_1
# 21    Aardvark web crawler for Sun's Blog recommenda...  id_a_f_250408_2
# 22                            Abacho / Crawler.de robot        id_a_f_13
# 23                            Abacho / Crawler.de robot        id_a_f_14
# 24    ABCdatos - Castilian program & tutorial directory        id_a_f_15
# 25    Aberja Hybridsuchmaschine (Germany) link checking        id_a_f_16
# 26    Nameprotect copyright search robot (24.177.134.x)        id_a_f_17
# 27                                          About robot        id_a_f_18
# 28                   Accela Technology RSS feed crawler  id_a_f_051206_3
# 29                                 Accoona Search robot        id_a_f_19
# ...                                                 ...              ...
# 2429  Yoono - community based search (193.110.140.xx...  id_t_z_120606_1
# 2430  YottaCars bot - YottaCar car search engine ( 6...      id_t_z_1533
# 2431  YottaShopping bot - YottaShopping search engin...      id_t_z_1534
# 2432  Y!TunnelPro - Yahoo! Messenger companion user ...      id_t_z_1535
# 2433                          Z-Add online link checker      id_t_z_1536
# 2434                    Zao crawler for Kototoi Project      id_t_z_1537
# 2435                    Zao crawler for Kototoi Project      id_t_z_1538
# 2436                    Zao crawler for Kototoi Project      id_t_z_1539
# 2437  Zeus Internet Marketing Robot based on Webster...      id_t_z_1540
# 2438                 Zearchit German search / directory  id_t_z_111205_5
# 2439                    Ze.bz Moteur de Recherche robot  id_t_z_130106_2
# 2440                    Ze.bz Moteur de Recherche robot      id_t_z_1541
# 2441                          ZedZo Search (beta) robot  id_t_z_130806_2
# 2442     Zend PHP frameworks Zend_Http_Client component  id_t_z_210807_2
# 2443  Powerset Natural Language Search crawler (unde...  id_t_z_290208_2
# 2444                                Zerx search robot ?      id_t_z_1542
# 2445  Zeus Internet Marketing Robot (based on Webste...      id_t_z_1543
# 2446  Zeus Internet Marketing Robot (based on Webste...      id_t_z_1544
# 2447  Zeusbot robot for building the Ulsysseek.com i...  id_t_z_281105_1
# 2448  Unknown agent (server- or link checking ?) fro...      id_t_z_1545
# 2449                          Zipp.net web search robot      id_t_z_1546
# 2450                          Zipp.net web search robot      id_t_z_1547
# 2451                                  Zippyfinder robot      id_t_z_1548
# 2452                 Microsoft Zoo Tycoon 2 game client      id_t_z_1549
# 2453                 Zoom Search Engine software spider      id_t_z_1550
# 2454   collecting for machine learning; http://zscho...  id_t_z_160110_1
# 2455              zspider robot for a new search engine  id_t_z_280306_1
# 2456                                      Wisenut robot      id_t_z_1551
# 2457                   FM Scene soccer fan pages plugin  id_new_190610_1
# 2458                              PrevX security plugin  id_new_190610_2
#
#                                                   Link1  \
# 0                                http://www.sync2it.com
# 1                               http://www.unchaos.com/
# 2                               http://www.unchaos.com/
# 3                               http://www.unchaos.com/
# 4                                 http://www.sygol.com/
# 5     http://www.searchengineworld.com/cgi-bin/robot...
# 6                             http://www.dricas.com/dp/
# 7                               http://www.privoxy.org/
# 8                                  http://www.yahoo.com
# 9                                http://www.sitidi.net/
# 10                             http://www.die-kraehe.de
# 11                             http://www.123spider.de/
# 12                                  http://www.192.com/
# 13                         http://www.zipcommander.com/
# 14         http://www.2bone.com/links/linkchecker.shtml
# 15                             http://www.4anything.com
# 16    http://www.projecthoneypot.org/bsh_X19tb2RlPWd...
# 17             http://www.neofonie.de/loesungen/search/
# 18                        http://www.jet2web.net/portal
# 19    http://www.micro-sys.dk/products/keyword-resea...
# 20    http://www.micro-sys.dk/products/sitemap-gener...
# 21                        http://blogs.sun.com/plamere/
# 22                                http://www.abacho.com
# 23                                http://www.abacho.com
# 24                              http://www.abcdatos.com
# 25                                 http://www.aberja.de
# 26                          http://www.nameprotect.com/
# 27                                 http://www.about.com
# 28                           http://www.accelatech.com/
# 29                               http://www.accoona.com
# ...                                                 ...
# 2429                              http://www.yoono.com/
# 2430                          http://www.yottacars.com/
# 2431                      http://www.yottashopping.com/
# 2432                         http://www.ytunnelpro.com/
# 2433                   http://w3.z-add.co.uk/linkcheck/
# 2434                        http://www.kototoi.org/zao/
# 2435                        http://www.kototoi.org/zao/
# 2436                        http://www.kototoi.org/zao/
# 2437                         http://cyber-robotics.com/
# 2438                            http://www.zearchit.de/
# 2439                                  http://www.ze.bz/
# 2440                                  http://www.ze.bz/
# 2441                              http://www.zedzo.com/
# 2442  http://framework.zend.com/manual/en/zend.http....
# 2443                           http://www.powerset.com/
# 2444                               http://www.zerx.com/
# 2445                         http://cyber-robotics.com/
# 2446                         http://cyber-robotics.com/
# 2447                            http://www.zeusbot.com/
# 2448                                                NaN
# 2449                              http://www.zippp.net/
# 2450                              http://www.zippp.net/
# 2451                        http://www.zippyfinder.com/
# 2452                           http://www.zootycoon.com
# 2453                           http://www.wrensoft.com/
# 2454                                      141.65.161.xx
# 2455                    http://feedback.redkolibri.com/
# 2456                         http://www.wisenutbot.com/
# 2457                              http://www.fmscene.de
# 2458                               http://www.prevx.com
#
#                                                   Link2  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20          http://www.micro-sys.dk/developer/miggibot/
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 2429                                                NaN
# 2430                                                NaN
# 2431                                                NaN
# 2432                                                NaN
# 2433                                                NaN
# 2434                                                NaN
# 2435                                                NaN
# 2436                                                NaN
# 2437                         http://www.homepagesw.com/
# 2438                                                NaN
# 2439                                                NaN
# 2440                                                NaN
# 2441                                                NaN
# 2442                                                NaN
# 2443  http://www.amazon.com/gp/browse.html?node=3435361
# 2444                                                NaN
# 2445                                                NaN
# 2446                                                NaN
# 2447                           http://www.ulysseek.com/
# 2448                                                NaN
# 2449                                                NaN
# 2450                                                NaN
# 2451                                                NaN
# 2452                                                NaN
# 2453                                                NaN
# 2454                               http://www.zscho.de/
# 2455                                                NaN
# 2456                                                NaN
# 2457                                                NaN
# 2458                                                NaN
#
#                                                  String  \
# 0                 !Susie (http://www.sync2it.com/susie)
# 1     <a href='http://www.unchaos.com/'> UnChaos </a...
# 2     <a href='http://www.unchaos.com/'> UnChaos Bot...
# 3     <b> UnChaosBot From Chaos To Order UnChaos Hyb...
# 4          <http://www.sygol.com/> http://www.sygol.com
# 5     ( Robots.txt Validator http://www.searchengine...
# 6                  (DreamPassport/3.0; isao/MyDiGiRabi)
# 7                                         (Privoxy/1.0)
# 8                                       */Nutch-0.9-dev
# 9            +SitiDi.net/SitiDiBot/1.0 (+Have Good Day)
# 10    -DIE-KRAEHE- META-SEARCH-ENGINE/1.1 http://www...
# 11    123spider-Bot (Version: 1.02, powered by www.1...
# 12                                         192.comAgent
# 13    1st ZipCommander (Net) - http://www.zipcommand...
# 14               2Bone_LinkChecker/1.0 libwww-perl/5.64
# 15                       4anything.com LinkChecker v2.0
# 16                            8484 Boston Project v 1.0
# 17    :robot/1.0 (linux) ( admin e-mail: undefined h...
# 18                                      A-Online Search
# 19    A1 Keyword Research/1.0.2 (+http://www.micro-s...
# 20    A1 Sitemap Generator/1.0 (+http://www.micro-sy...
# 21                                     aardvark-crawler
# 22                                            AbachoBOT
# 23                       AbachoBOT (Mozilla compatible)
# 24                        ABCdatos BotLink/5.xx.xxx#BBL
# 25                                     Aberja Checkomat
# 26    abot/0.1 (abot; http://www.abot.com; abot@abot...
# 27                            About/0.1libwww-perl/5.47
# 28                            Accelatech RSSCrawler/0.4
# 29                                              accoona
# ...                                                 ...
# 2429                          yoono/1.0 web-crawler/1.0
# 2430  YottaCars_Bot/4.12 (+http://www.yottacars.com)...
# 2431  YottaShopping_Bot/4.12 (+http://www.yottashopp...
# 2432                                         YTunnelPro
# 2433  Z-Add Link Checker (http://w3.z-add.co.uk/link...
# 2434                                        Zao-Crawler
# 2435                                   Zao-Crawler 0.2b
# 2436              Zao/0.1 (http://www.kototoi.org/zao/)
# 2437                    ZBot/1.00 (icaulfield@zeus.com)
# 2438                                           Zearchit
# 2439                        ZeBot_lseek.net (bot@ze.bz)
# 2440                ZeBot_www.ze.bz (ze.bz@hotmail.com)
# 2441           zedzo.digest/0.1 (http://www.zedzo.com/)
# 2442                                   Zend_Http_Client
# 2443  zermelo Mozilla/5.0 compatible; heritrix/1.12....
# 2444               zerxbot/Version 0.6 libwww-perl/5.79
# 2445       Zeus ThemeSite Viewer Webster Pro V2.9 Win32
# 2446                  Zeus xxxxx Webster Pro V2.9 Win32
# 2447  Zeusbot/0.07 (Ulysseek's web-crawling robot; h...
# 2448                     Ziggy -- The Clown From Hell!!
# 2449  ZipppBot/0.xx (ZipppBot; http://www.zippp.net;...
# 2450  ZIPPPCVS/0.xx (ZipppBot/.xx;http://www.zippp.n...
# 2451                       Zippy v2.0 - Zippyfinder.com
# 2452    Zoo Tycoon 2 Client -- http://www.zootycoon.com
# 2453                          ZoomSpider - wrensoft.com
# 2454  Zscho.de Crawler/Nutch-1.0-Zscho.de-semantic_p...
# 2455    zspider/0.9-dev http://feedback.redkolibri.com/
# 2456  ZyBorg/1.0 (ZyBorg@WISEnut.com; http://www.WIS...
# 2457  Mozilla/5.0 (Windows; U; Windows NT 5.1; de; r...
# 2458  Mozilla/5.0 (Windows; U; Windows NT 5.1; de; r...
#
#                                 Type user-agent
# 0                                C R         \n
# 1                                  R         \n
# 2                                  R         \n
# 3                                  R         \n
# 4                                  R         \n
# 5                                  C         \n
# 6                                  B         \n
# 7                                  P         \n
# 8                                  R         \n
# 9                                  R         \n
# 10                                 R         \n
# 11                                 C         \n
# 12                                 R         \n
# 13                                 B         \n
# 14                                 C         \n
# 15                                 R         \n
# 16                                 S         \n
# 17                                 R         \n
# 18                                 R         \n
# 19                                 C         \n
# 20                                 R         \n
# 21                                 R         \n
# 22                                 R         \n
# 23                                 R         \n
# 24                                 R         \n
# 25                                 R         \n
# 26                                 R         \n
# 27                                 R         \n
# 28                                 R         \n
# 29                                 R         \n
# ...                              ...        ...
# 2429                               R         \n
# 2430                               R         \n
# 2431                               R         \n
# 2432                               B         \n
# 2433                               C         \n
# 2434                               R         \n
# 2435                               R         \n
# 2436                               R         \n
# 2437                               R         \n
# 2438                               R         \n
# 2439                               R         \n
# 2440                               R         \n
# 2441                               R         \n
# 2442                               D         \n
# 2443                               R         \n
# 2444                               R         \n
# 2445                               R         \n
# 2446                               R         \n
# 2447                               R         \n
# 2448                               C         \n
# 2449                               R         \n
# 2450                               R         \n
# 2451                               R         \n
# 2452                               B         \n
# 2453                               R         \n
# 2454  Zscho search crawler (Germany)         \n
# 2455                               R         \n
# 2456                               R         \n
# 2457                               L         \n
# 2458                             NaN         \n
#
# [2459 rows x 8 columns]

# %%
import xmldataset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-727ec287da82> in <module>()
# ----> 1 import xmldataset
#
# ImportError: No module named 'xmldataset'
